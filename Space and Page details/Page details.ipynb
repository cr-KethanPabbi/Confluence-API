# %%
import sys
import csv
import requests
sys.path.append("..")  # Add the parent directory to the sys.path
from config import CR_EMAIL, API_KEY, BASE_URL
# Out:
# /Users/kethan/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# spaces 1-1000
def save_page_details_to_csv(page_details, filename):
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Space Name', 'Page Name', 'Created By', 'Last Modified By', 'Last Modified Date', 'Views', 'Web URL'])
        for page in page_details:
            writer.writerow([
                page['space_name'],
                page['page_name'],
                page['created_by'],
                page['last_modified_by'],
                page['last_modified_date'],
                page['views'],
                page['web_url']
            ])

def get_total_unique_spaces_and_pages_in_confluence():
    email = CR_EMAIL
    api_token = API_KEY
    auth = (email, api_token)
    base_url = "https://cybereason.atlassian.net/wiki/"
    unique_spaces = set()
    page_details = []

    # Make request to Confluence API to get total number of spaces
    limit_spaces = 10000  # Adjust the limit as needed
    start_spaces = 0

    try:
        # Fetch spaces
        while True:
            spaces_response = requests.get(base_url + f"rest/api/space?start={start_spaces}&limit={limit_spaces}", auth=auth)
            spaces_data = spaces_response.json()
            current_spaces = spaces_data.get('results', [])

            # Loop through each space
            for space in current_spaces:
                space_key = space.get('key')
                space_name = space.get('name')
                unique_spaces.add(space_key)

                # Make request to Confluence API to get total number of pages for current space
                pages_response = requests.get(base_url + f"rest/api/content?spaceKey={space_key}&limit=1000", auth=auth)
                pages_data = pages_response.json().get('results', [])

                # Display space name
                print("Space Name:", space_name)

                # Loop through each page in the current space
                for page in pages_data:
                    page_id = page.get('id')
                    page_name = page.get('title', 'Unknown')
                    
                    # Fetch detailed information about the page
                    page_details_response = requests.get(base_url + f"rest/api/content/{page_id}", auth=auth)
                    page_details_data = page_details_response.json()
                    
                    creator = page_details_data.get('history', {}).get('createdBy', {}).get('displayName', 'Unknown')
                    
                    # Fetching last modified information from version
                    last_modified_info = page_details_data.get('version', {}).get('by', {})
                    last_modifier = last_modified_info.get('displayName', 'Unknown')
                    last_modified_date = page_details_data.get('version', {}).get('friendlyWhen', 'Unknown')
                    
                    # Fetch views for the page
                    views_response = requests.get(base_url + f"rest/api/analytics/content/{page_id}/views", auth=auth)
                    views_data = views_response.json().get('count', 'Unknown')
                    
                    web_url = page_details_data.get('_links', {}).get('webui')
                    
                    # Add page details to the list
                    page_details.append({
                        'space_name': space_name,
                        'page_name': page_name,
                        'created_by': creator,
                        'last_modified_by': last_modifier,
                        'last_modified_date': last_modified_date,
                        'views': views_data,
                        'web_url': base_url + web_url
                    })

                # Display total unique pages for current space
                print("Total Unique Pages in this space:", len(pages_data))
                print()  # Add a blank line for separation

            # Check if there are more spaces to fetch
            start_spaces += limit_spaces
            if 'next' not in spaces_data['_links']:
                break

        total_unique_spaces = len(unique_spaces)
        print("\nTotal unique spaces in Confluence:", total_unique_spaces)
        print("Total unique pages in Confluence:", len(page_details))

        # Save page details to CSV
        save_page_details_to_csv(page_details, 'confluence_pages.csv')

        return {"total_unique_spaces": total_unique_spaces, "total_unique_pages": len(page_details)}

    except KeyboardInterrupt:
        print("\nKeyboard interrupt detected. Saving current progress to CSV...")
        save_page_details_to_csv(page_details, 'confluence_pages_interrupted.csv')
        print("Current progress saved.")
        sys.exit(0)

    except Exception as e:
        print("An error occurred:", str(e))
        print("Saving current progress to CSV...")
        save_page_details_to_csv(page_details, 'confluence_pages_interrupted.csv')
        print("Current progress saved.")
        sys.exit(1)

get_total_unique_spaces_and_pages_in_confluence()

# %%
# spaces 1001 and above
def save_page_details_to_csv(page_details, filename):
    with open(filename, mode='a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        for page in page_details:
            writer.writerow([
                page['space_name'],
                page['page_name'],
                page['created_by'],
                page['last_modified_by'],
                page['last_modified_date'],
                page['views'],
                page['web_url']
            ])

def get_total_unique_spaces_and_pages_in_confluence(start_index=0):
    email = CR_EMAIL
    api_token = API_KEY
    auth = (email, api_token)
    base_url = "https://cybereason.atlassian.net/wiki/"
    unique_spaces = set()
    page_details = []

    # Make request to Confluence API to get total number of spaces
    limit_spaces = 10000  # Adjust the limit as needed
    start_spaces = start_index

    try:
        # Fetch spaces
        while True:
            spaces_response = requests.get(base_url + f"rest/api/space?start={start_spaces}&limit={limit_spaces}", auth=auth)
            spaces_data = spaces_response.json()
            current_spaces = spaces_data.get('results', [])

            # Loop through each space
            for space in current_spaces:
                space_key = space.get('key')
                space_name = space.get('name')
                unique_spaces.add(space_key)

                # Make request to Confluence API to get total number of pages for current space
                pages_response = requests.get(base_url + f"rest/api/content?spaceKey={space_key}&limit=1000", auth=auth)
                pages_data = pages_response.json().get('results', [])

                # Display space name
                print("Space Name:", space_name)

                # Loop through each page in the current space
                for page in pages_data:
                    page_id = page.get('id')
                    page_name = page.get('title', 'Unknown')
                    
                    # Fetch detailed information about the page
                    page_details_response = requests.get(base_url + f"rest/api/content/{page_id}", auth=auth)
                    page_details_data = page_details_response.json()
                    
                    creator = page_details_data.get('history', {}).get('createdBy', {}).get('displayName', 'Unknown')
                    
                    # Fetching last modified information from version
                    last_modified_info = page_details_data.get('version', {}).get('by', {})
                    last_modifier = last_modified_info.get('displayName', 'Unknown')
                    last_modified_date = page_details_data.get('version', {}).get('friendlyWhen', 'Unknown')
                    
                    # Fetch views for the page
                    views_response = requests.get(base_url + f"rest/api/analytics/content/{page_id}/views", auth=auth)
                    views_data = views_response.json().get('count', 'Unknown')
                    
                    web_url = page_details_data.get('_links', {}).get('webui')
                    
                    # Add page details to the list
                    page_details.append({
                        'space_name': space_name,
                        'page_name': page_name,
                        'created_by': creator,
                        'last_modified_by': last_modifier,
                        'last_modified_date': last_modified_date,
                        'views': views_data,
                        'web_url': base_url + web_url
                    })

                # Display total unique pages for current space
                print("Total Unique Pages in this space:", len(pages_data))
                print()  # Add a blank line for separation

            # Check if there are more spaces to fetch
            start_spaces += limit_spaces
            if 'next' not in spaces_data['_links']:
                break

        total_unique_spaces = len(unique_spaces)
        print("\nTotal unique spaces in Confluence:", total_unique_spaces)
        print("Total unique pages in Confluence:", len(page_details))

        # Save page details to CSV
        save_page_details_to_csv(page_details, 'confluence_pages(1000+).csv')

        return {"total_unique_spaces": total_unique_spaces, "total_unique_pages": len(page_details)}

    except KeyboardInterrupt:
        print("\nKeyboardInterrupt detected.")
        print("Saving current progress to CSV...")
        save_page_details_to_csv(page_details, 'confluence_pages_interrupted.csv')
        print("Current progress saved.")
        sys.exit(0)

    except Exception as e:
        print("An error occurred:", str(e))
        print("Saving current progress to CSV...")
        save_page_details_to_csv(page_details, 'confluence_pages_interrupted.csv')
        print("Current progress saved.")
        sys.exit(1)

get_total_unique_spaces_and_pages_in_confluence(start_index=1001)
# Out:
# Space Name: Noa.Fisher
# Total Unique Pages in this space: 5
#
# Space Name: noam.gandelman
# Total Unique Pages in this space: 5
#
# Space Name: noam.guy
# Total Unique Pages in this space: 5
#
# Space Name: Noam Katzenelson
# Total Unique Pages in this space: 5
#
# Space Name: Noam Ozer
# Total Unique Pages in this space: 5
#
# Space Name: noam.yair
# Total Unique Pages in this space: 5
#
# Space Name: Noa Ohev Shalom
# Total Unique Pages in this space: 5
#
# Space Name: Noa Stern Dekel
# Total Unique Pages in this space: 3
#
# Space Name: Nobuyuki Kimura
# Total Unique Pages in this space: 5
#
# Space Name: nobuyuki kuriyama
# Total Unique Pages in this space: 5
#
# Space Name: Nofar Gez
# Total Unique Pages in this space: 5
#
# Space Name: Noirin Ni Dhomhnaill
# Total Unique Pages in this space: 5
#
# Space Name: Noora Rautiainen
# Total Unique Pages in this space: 1
#
# Space Name: Norihiro Watanabe
# Total Unique Pages in this space: 5
#
# Space Name: Norihisa Takagi
# Total Unique Pages in this space: 5
#
# Space Name: noritaka.kitamura
# Total Unique Pages in this space: 5
#
# Space Name: noy.maday
# Total Unique Pages in this space: 5
#
# Space Name: nufar.enoch
# Total Unique Pages in this space: 5
#
# Space Name: Nur Shemesh
# Total Unique Pages in this space: 5
#
# Space Name: Nuttawud Nutchanat
# Total Unique Pages in this space: 5
#
# Space Name: Observability
# Total Unique Pages in this space: 43
#
# Space Name: OCSO - Public space
# Total Unique Pages in this space: 120
#
# Space Name: OCTO - Innovation
# Total Unique Pages in this space: 4
#
# Space Name: Ofek
# Total Unique Pages in this space: 5
#
# Space Name: Ofek Carmel
# Total Unique Pages in this space: 5
#
# Space Name: Ofek Vardi
# Total Unique Pages in this space: 5
#
# Space Name: Ofer Azulay
# Total Unique Pages in this space: 5
#
# Space Name: Office of the CSO
# Total Unique Pages in this space: 1
#
# Space Name: Office of the CSO
# Total Unique Pages in this space: 133
#
# Space Name: officesupport_jp
# Total Unique Pages in this space: 1
#
# Space Name: Ofir.Ozer
# Total Unique Pages in this space: 5
#
# Space Name: Ofir Sonsino
# Total Unique Pages in this space: 5
#
# Space Name: ofir.tal
# Total Unique Pages in this space: 5
#
# Space Name: Ofri Sela
# Total Unique Pages in this space: 5
#
# Space Name: ohad.raz
# Total Unique Pages in this space: 5
#
# Space Name: Ohad Sharabany
# Total Unique Pages in this space: 5
#
# Space Name: ohav.peri
# Total Unique Pages in this space: 6
#
# Space Name: oleg.davidov
# Total Unique Pages in this space: 5
#
# Space Name: Oleksandr Chaika
# Total Unique Pages in this space: 5
#
# Space Name: oleksandr.svyrydenko
# Total Unique Pages in this space: 5
#
# Space Name: Oleksii Mosiichuk
# Total Unique Pages in this space: 5
#
# Space Name: Oleksii Zapryvoda
# Total Unique Pages in this space: 5
#
# Space Name: Olga Sherer
# Total Unique Pages in this space: 1
#
# Space Name: Olivier Cateysson
# Total Unique Pages in this space: 5
#
# Space Name: omer.eilat
# Total Unique Pages in this space: 5
#
# Space Name: Omer Galiko
# Total Unique Pages in this space: 1
#
# Space Name: Omer Haider
# Total Unique Pages in this space: 5
#
# Space Name: omer.mazig
# Total Unique Pages in this space: 5
#
# Space Name: omer.mizrahi
# Total Unique Pages in this space: 5
#
# Space Name: Omer_Palombo
# Total Unique Pages in this space: 5
#
# Space Name: Omer  Zur
# Total Unique Pages in this space: 5
#
# Space Name: Omri Ben Ari
# Total Unique Pages in this space: 1
#
# Space Name: Omri Cohen
# Total Unique Pages in this space: 5
#
# Space Name: Omri Elmaliach
# Total Unique Pages in this space: 5
#
# Space Name: omri.manor
# Total Unique Pages in this space: 5
#
# Space Name: Omri.Norber
# Total Unique Pages in this space: 5
#
# Space Name: Omri Refaeli
# Total Unique Pages in this space: 5
#
# Space Name: omry.chernenkov
# Total Unique Pages in this space: 5
#
# Space Name: Onai Gwachiwa
# Total Unique Pages in this space: 5
#
# Space Name: orel.cohen
# Total Unique Pages in this space: 8
#
# Space Name: Oren Ofer
# Total Unique Pages in this space: 5
#
# Space Name: oren.shamir
# Total Unique Pages in this space: 5
#
# Space Name: Oren Yekutieli
# Total Unique Pages in this space: 10
#
# Space Name: Or Golov
# Total Unique Pages in this space: 5
#
# Space Name: Or Hazut
# Total Unique Pages in this space: 5
#
# Space Name: ori.bachar
# Total Unique Pages in this space: 5
#
# Space Name: Ori Cohen
# Total Unique Pages in this space: 5
#
# Space Name: ori.herman
# Total Unique Pages in this space: 5
#
# Space Name: ori.kfir
# Total Unique Pages in this space: 5
#
# Space Name: ori.libhaber
# Total Unique Pages in this space: 5
#
# Space Name: Ori Vardi
# Total Unique Pages in this space: 5
#
# Space Name: ori.zuckerman
# Total Unique Pages in this space: 5
#
# Space Name: Or Kunst
# Total Unique Pages in this space: 5
#
# Space Name: orli.solomon
# Total Unique Pages in this space: 5
#
# Space Name: Or.Nachmias
# Total Unique Pages in this space: 5
#
# Space Name: Orolbai Kamchibekov
# Total Unique Pages in this space: 5
#
# Space Name: osnat.tischler
# Total Unique Pages in this space: 5
#
# Space Name: osnat.tsook
# Total Unique Pages in this space: 5
#
# Space Name: Oussama GABI
# Total Unique Pages in this space: 5
#
# Space Name: Ovidiu Alexa
# Total Unique Pages in this space: 5
#
# Space Name: oyunbold.myagmarsuren
# Total Unique Pages in this space: 5
#
# Space Name: Paarkavi Dhanasekar
# Total Unique Pages in this space: 5
#
# Space Name: parin.sachedina
# Total Unique Pages in this space: 5
#
# Space Name: Partner Success
# Total Unique Pages in this space: 147
#
# Space Name: Partner Success Japan
# Total Unique Pages in this space: 51
#
# Space Name: Patrick Shea
# Total Unique Pages in this space: 1
#
# Space Name: Paul Bottomley
# Total Unique Pages in this space: 5
#
# Space Name: Paul  Crawford
# Total Unique Pages in this space: 5
#
# Space Name: Paul Gogu
# Total Unique Pages in this space: 5
#
# Space Name: Paul Gregory
# Total Unique Pages in this space: 5
#
# Space Name: Paul  Knott
# Total Unique Pages in this space: 5
#
# Space Name: Paul Peck
# Total Unique Pages in this space: 5
#
# Space Name: Pavel Mucha
# Total Unique Pages in this space: 5
#
# Space Name: Pawel Jan Wegner
# Total Unique Pages in this space: 1
#
# Space Name: Pawel Madejski
# Total Unique Pages in this space: 5
#
# Space Name: Pazit Belisha
# Total Unique Pages in this space: 5
#
# Space Name: Pedro Ferreira
# Total Unique Pages in this space: 5
#
# Space Name: Penny Brand
# Total Unique Pages in this space: 5
#
# Space Name: People Home
# Total Unique Pages in this space: 88
#
# Space Name: People Ops
# Total Unique Pages in this space: 39
#
# Space Name: People Ops - TLV
# Total Unique Pages in this space: 11
#
# Space Name: People Support
# Total Unique Pages in this space: 1
#
# Space Name: PeopleSupport_JP
# Total Unique Pages in this space: 1
#
# Space Name: Performance-infra
# Total Unique Pages in this space: 378
#
# Space Name: petar.krastev
# Total Unique Pages in this space: 5
#
# Space Name: Peter Freeman
# Total Unique Pages in this space: 5
#
# Space Name: Peter McGinnis
# Total Unique Pages in this space: 4
#
# Space Name: peter.moote
# Total Unique Pages in this space: 5
#
# Space Name: Peter Ortiz
# Total Unique Pages in this space: 5
#
# Space Name: Petro.Diachenko
# Total Unique Pages in this space: 5
#
# Space Name: phil.karcher
# Total Unique Pages in this space: 5
#
# Space Name: Pierre Buijsman
# Total Unique Pages in this space: 5
#
# Space Name: Piotr Owsianko
# Total Unique Pages in this space: 5
#
# Space Name: Piotr Wojtyla
# Total Unique Pages in this space: 5
#
# Space Name: Piyush Kohli
# Total Unique Pages in this space: 5
#
# Space Name: Pre Execution
# Total Unique Pages in this space: 34
#
# Space Name: Presales Hunting
# Total Unique Pages in this space: 7
#
# Space Name: Procurement
# Total Unique Pages in this space: 1
#
# Space Name: Product
# Total Unique Pages in this space: 989
#
# Space Name: Production Group
# Total Unique Pages in this space: 41
#
# Space Name: Production Readiness Forms
# Total Unique Pages in this space: 55
#
# Space Name: Product Marketing
# Total Unique Pages in this space: 33
#
# Space Name: Protect
# Total Unique Pages in this space: 17
#
# Space Name: Pujitha Kattekola
# Total Unique Pages in this space: 1
#
# Space Name: QA Chapter
# Total Unique Pages in this space: 160
#
# Space Name: QA Cost
# Total Unique Pages in this space: 148
#
# Space Name: Rafel Ivgi
# Total Unique Pages in this space: 1
#
# Space Name: Rahul Saggar
# Total Unique Pages in this space: 5
#
# Space Name: Raimar Melchior
# Total Unique Pages in this space: 5
#
# Space Name: Rakesh Vyas
# Total Unique Pages in this space: 1
#
# Space Name: Rakia Offer
# Total Unique Pages in this space: 1
#
# Space Name: ralph.villanueva
# Total Unique Pages in this space: 5
#
# Space Name: Ram Binyamin
# Total Unique Pages in this space: 5
#
# Space Name: Ram Golla
# Total Unique Pages in this space: 5
#
# Space Name: ramon.danieli
# Total Unique Pages in this space: 5
#
# Space Name: ran.eylat
# Total Unique Pages in this space: 5
#
# Space Name: ranny.avidan
# Total Unique Pages in this space: 5
#
# Space Name: Ran Ravid
# Total Unique Pages in this space: 5
#
# Space Name: ran.shemesh
# Total Unique Pages in this space: 7
#
# Space Name: Ran Weiner
# Total Unique Pages in this space: 5
#
# Space Name: raul.zayat
# Total Unique Pages in this space: 5
#
# Space Name: Ravi Iyer
# Total Unique Pages in this space: 5
#
# Space Name: ravit.levi
# Total Unique Pages in this space: 5
#
# Space Name: Raz Isaac
# Total Unique Pages in this space: 1
#
# Space Name: raz.kat
# Total Unique Pages in this space: 46
#
# Space Name: raz.rogek
# Total Unique Pages in this space: 5
#
# Space Name: Razvan Zavate
# Total Unique Pages in this space: 5
#
# Space Name: Rebecca Barry
# Total Unique Pages in this space: 5
#
# Space Name: rebecca.howarth
# Total Unique Pages in this space: 5
#
# Space Name: regina.ivgi
# Total Unique Pages in this space: 5
#
# Space Name: rei akiyama
# Total Unique Pages in this space: 5
#
# Space Name: reina.hirate
# Total Unique Pages in this space: 4
#
# Space Name: Reina Iida
# Total Unique Pages in this space: 5
#
# Space Name: Renato Mondio
# Total Unique Pages in this space: 5
#
# Space Name: René Vokal
# Total Unique Pages in this space: 5
#
# Space Name: Reo Matsui
# Total Unique Pages in this space: 1
#
# Space Name: Reo Mukudai
# Total Unique Pages in this space: 5
#
# Space Name: reona.nakamura
# Total Unique Pages in this space: 5
#
# Space Name: Richard Mutabazi
# Total Unique Pages in this space: 5
#
# Space Name: Rich Hughes
# Total Unique Pages in this space: 5
#
# Space Name: Rick Zandier
# Total Unique Pages in this space: 5
#
# Space Name: rika.takahashi
# Total Unique Pages in this space: 5
#
# Space Name: rina bruter
# Total Unique Pages in this space: 5
#
# Space Name: rinat.shlomo
# Total Unique Pages in this space: 5
#
# Space Name: Rizwan Khan
# Total Unique Pages in this space: 5
#
# Space Name: robert.cameron
# Total Unique Pages in this space: 5
#
# Space Name: Robert Clark
# Total Unique Pages in this space: 5
#
# Space Name: Robert Cole-Lomas
# Total Unique Pages in this space: 5
#
# Space Name: robert.greenwell
# Total Unique Pages in this space: 5
#
# Space Name: Robert Lourenco
# Total Unique Pages in this space: 6
#
# Space Name: Roberto Arico
# Total Unique Pages in this space: 5
#
# Space Name: Robert Zelazo
# Total Unique Pages in this space: 5
#
# Space Name: Robin Plumer
# Total Unique Pages in this space: 0
#
# Space Name: Roey Azroel
# Total Unique Pages in this space: 5
#
# Space Name: Rohit Ambadas
# Total Unique Pages in this space: 5
#
# Space Name: Roman Fayer
# Total Unique Pages in this space: 5
#
# Space Name: Roman Kurtsman
# Total Unique Pages in this space: 5
#
# Space Name: Romina Inger
# Total Unique Pages in this space: 5
#
# Space Name: ron.amar
# Total Unique Pages in this space: 5
#
# Space Name: Ron Balter
# Total Unique Pages in this space: 14
#
# Space Name: Ronen Chen
# Total Unique Pages in this space: 6
#
# Space Name: Ronen Zaslaver
# Total Unique Pages in this space: 5
#
# Space Name: roni schwartz
# Total Unique Pages in this space: 5
#
# Space Name: ron.lazarovich
# Total Unique Pages in this space: 5
#
# Space Name: ronny.lev-or
# Total Unique Pages in this space: 5
#
# Space Name: Ron Peled
# Total Unique Pages in this space: 5
#
# Space Name: Ron Salinas
# Total Unique Pages in this space: 1
#
# Space Name: Rose Cruz
# Total Unique Pages in this space: 7
#
# Space Name: Ross Duncan
# Total Unique Pages in this space: 5
#
# Space Name: Rotem Dagan
# Total Unique Pages in this space: 5
#
# Space Name: rotem.levi
# Total Unique Pages in this space: 5
#
# Space Name: rotem.rostami
# Total Unique Pages in this space: 5
#
# Space Name: Rotem Wiesen
# Total Unique Pages in this space: 5
#
# Space Name: Roy Akerman
# Total Unique Pages in this space: 1
#
# Space Name: Roy.Asulin
# Total Unique Pages in this space: 5
#
# Space Name: Roy Bar Oz
# Total Unique Pages in this space: 1
#
# Space Name: royee.shemesh
# Total Unique Pages in this space: 5
#
# Space Name: Roy Eldar
# Total Unique Pages in this space: 5
#
# Space Name: roy.ido
# Total Unique Pages in this space: 5
#
# Space Name: roy.soldin
# Total Unique Pages in this space: 5
#
# Space Name: roy.zwebner
# Total Unique Pages in this space: 5
#
# Space Name: Rumi Sawada
# Total Unique Pages in this space: 5
#
# Space Name: Rupen.Parmar
# Total Unique Pages in this space: 5
#
# Space Name: ruslan.pasichniuk
# Total Unique Pages in this space: 5
#
# Space Name: Ruslan Rustchev
# Total Unique Pages in this space: 5
#
# Space Name: ruth.nana
# Total Unique Pages in this space: 5
#
# Space Name: ryan.bialecki
# Total Unique Pages in this space: 5
#
# Space Name: Ryan Davis
# Total Unique Pages in this space: 5
#
# Space Name: Ryan Gecelter
# Total Unique Pages in this space: 5
#
# Space Name: Ryan Simpson
# Total Unique Pages in this space: 5
#
# Space Name: ryo.tomizawa
# Total Unique Pages in this space: 5
#
# Space Name: Ryoto Tanaka
# Total Unique Pages in this space: 5
#
# Space Name: ryuzo okudera
# Total Unique Pages in this space: 5
#
# Space Name: saar.grin
# Total Unique Pages in this space: 5
#
# Space Name: Sabrina Pinnu
# Total Unique Pages in this space: 5
#
# Space Name: Saburo Mori
# Total Unique Pages in this space: 5
#
# Space Name: Sadanobu Oshita
# Total Unique Pages in this space: 5
#
# Space Name: Safet Safet
# Total Unique Pages in this space: 1
#
# Space Name: Sagi Sinvani
# Total Unique Pages in this space: 5
#
# Space Name: Sagiv Masvari
# Total Unique Pages in this space: 81
#
# Space Name: Sagi Zeevi
# Total Unique Pages in this space: 5
#
# Space Name: Sahar Rabinovich
# Total Unique Pages in this space: 1
#
# Space Name: Sales
# Total Unique Pages in this space: 15
#
# Space Name: Sales Engineering
# Total Unique Pages in this space: 264
#
# Space Name: Salesforce
# Total Unique Pages in this space: 14
#
# Space Name: Sales Tax
# Total Unique Pages in this space: 1
#
# Space Name: Sam Curry
# Total Unique Pages in this space: 5
#
# Space Name: Samith.Premaratne
# Total Unique Pages in this space: 5
#
# Space Name: Samuel Desnos
# Total Unique Pages in this space: 5
#
# Space Name: Samy Younsi
# Total Unique Pages in this space: 1
#
# Space Name: sanae.takada
# Total Unique Pages in this space: 5
#
# Space Name: Sanat
# Total Unique Pages in this space: 5
#
# Space Name: Saori Hashimoto
# Total Unique Pages in this space: 5
#
# Space Name: sapir yehie
# Total Unique Pages in this space: 5
#
# Space Name: Sarah Baileigh
# Total Unique Pages in this space: 5
#
# Space Name: Sarah Geary
# Total Unique Pages in this space: 5
#
# Space Name: Sarah Gowing
# Total Unique Pages in this space: 1
#
# Space Name: Sara Munzinger
# Total Unique Pages in this space: 5
#
# Space Name: Sari Nashef
# Total Unique Pages in this space: 5
#
# Space Name: Satoko Moriyama
# Total Unique Pages in this space: 5
#
# Space Name: Satoru Miyajima
# Total Unique Pages in this space: 5
#
# Space Name: Satoru Nagase
# Total Unique Pages in this space: 5
#
# Space Name: Satoshi Ogawa
# Total Unique Pages in this space: 5
#
# Space Name: Satoshi Tsurusaki
# Total Unique Pages in this space: 5
#
# Space Name: saul.magdaleno
# Total Unique Pages in this space: 5
#
# Space Name: SAVE squad
# Total Unique Pages in this space: 28
#
# Space Name: Sean McLelland
# Total Unique Pages in this space: 5
#
# Space Name: Sebastiaan Back
# Total Unique Pages in this space: 5
#
# Space Name: SecOps
# Total Unique Pages in this space: 443
#
# Space Name: Security Content Management
# Total Unique Pages in this space: 6
#
# Space Name: Security Platform
# Total Unique Pages in this space: 3
#
# Space Name: Security Research
# Total Unique Pages in this space: 1000
#
# Space Name: Sei Ki
# Total Unique Pages in this space: 5
#
# Space Name: Seiya Kabasawa
# Total Unique Pages in this space: 5
#
# Space Name: Selim DOUCENE
# Total Unique Pages in this space: 5
#
# Space Name: semyon
# Total Unique Pages in this space: 5
#
# Space Name: Sensor Automation Infra
# Total Unique Pages in this space: 59
#
# Space Name: Sensor configuration
# Total Unique Pages in this space: 1
#
# Space Name: Sensor Deployment
# Total Unique Pages in this space: 148
#
# Space Name: Sensor Platform
# Total Unique Pages in this space: 192
#
# Space Name: Sergei
# Total Unique Pages in this space: 5
#
# Space Name: Sergio Marchesi
# Total Unique Pages in this space: 1
#
# Space Name: Serhii Malyshev
# Total Unique Pages in this space: 1
#
# Space Name: Serhii Samoshkin
# Total Unique Pages in this space: 5
#
# Space Name: Server Chapter
# Total Unique Pages in this space: 149
#
# Space Name: Shabtay Barel
# Total Unique Pages in this space: 5
#
# Space Name: Shachar Kaplan
# Total Unique Pages in this space: 5
#
# Space Name: Shachar Lavie
# Total Unique Pages in this space: 5
#
# Space Name: Shahaf Azriely
# Total Unique Pages in this space: 5
#
# Space Name: shahar.eldar
# Total Unique Pages in this space: 5
#
# Space Name: shahar.nissinboim
# Total Unique Pages in this space: 5
#
# Space Name: Shai Demri
# Total Unique Pages in this space: 5
#
# Space Name: Shai.Forte
# Total Unique Pages in this space: 5
#
# Space Name: Shai Levi
# Total Unique Pages in this space: 5
#
# Space Name: Shalev Elhaiany
# Total Unique Pages in this space: 1
#
# Space Name: shalom.chamami
# Total Unique Pages in this space: 5
#
# Space Name: shalom.kramer
# Total Unique Pages in this space: 5
#
# Space Name: Shalom Shmila
# Total Unique Pages in this space: 5
#
# Space Name: Shanhav Buzaglo
# Total Unique Pages in this space: 5
#
# Space Name: shani.golan
# Total Unique Pages in this space: 5
#
# Space Name: Shani Kahlon
# Total Unique Pages in this space: 5
#
# Space Name: Shani Mantzur
# Total Unique Pages in this space: 7
#
# Space Name: Sharon Lowe
# Total Unique Pages in this space: 5
#
# Space Name: Sharon Ofgang
# Total Unique Pages in this space: 1
#
# Space Name: Shawn Mullican
# Total Unique Pages in this space: 5
#
# Space Name: Shay Arad
# Total Unique Pages in this space: 5
#
# Space Name: shayna.strum
# Total Unique Pages in this space: 5
#
# Space Name: shayne.obrien
# Total Unique Pages in this space: 5
#
# Space Name: Shelly Bar-On
# Total Unique Pages in this space: 5
#
# Space Name: Shelly Malichi
# Total Unique Pages in this space: 5
#
# Space Name: Sherry Li
# Total Unique Pages in this space: 5
#
# Space Name: shigeo.doi
# Total Unique Pages in this space: 5
#
# Space Name: Shigeyasu Tanaka
# Total Unique Pages in this space: 5
#
# Space Name: shilo.drot
# Total Unique Pages in this space: 6
#
# Space Name: Shinichi Adachi
# Total Unique Pages in this space: 5
#
# Space Name: shinsuke.honjo
# Total Unique Pages in this space: 5
#
# Space Name: Shinsuke Ikeda
# Total Unique Pages in this space: 5
#
# Space Name: shira.bar.yosef
# Total Unique Pages in this space: 5
#
# Space Name: shira.rotem-koblenz
# Total Unique Pages in this space: 5
#
# Space Name: shira.rotman
# Total Unique Pages in this space: 5
#
# Space Name: Shir Elmaliach
# Total Unique Pages in this space: 5
#
# Space Name: Shiri Cohen
# Total Unique Pages in this space: 5
#
# Space Name: Shiri Levy
# Total Unique Pages in this space: 5
#
# Space Name: shirly.bittan
# Total Unique Pages in this space: 5
#
# Space Name: Shirly Jackobovitz
# Total Unique Pages in this space: 5
#
# Space Name: Shirly Tamari
# Total Unique Pages in this space: 5
#
# Space Name: Shir Tamir
# Total Unique Pages in this space: 1
#
# Space Name: Shir Yerushalmi
# Total Unique Pages in this space: 5
#
# Space Name: Shlomi Dori
# Total Unique Pages in this space: 1
#
# Space Name: Shlomi Hazan
# Total Unique Pages in this space: 1
#
# Space Name: shogo.shibutani
# Total Unique Pages in this space: 5
#
# Space Name: Shoichi Shimizu
# Total Unique Pages in this space: 5
#
# Space Name: shon.avri
# Total Unique Pages in this space: 5
#
# Space Name: Shon David
# Total Unique Pages in this space: 5
#
# Space Name: Shoshana Avni
# Total Unique Pages in this space: 5
#
# Space Name: Sho Takeuchi1¥
# Total Unique Pages in this space: 5
#
# Space Name: Shoval Swissa
# Total Unique Pages in this space: 5
#
# Space Name: shuhei.takashi
# Total Unique Pages in this space: 5
#
# Space Name: shuichi.ohkubo
# Total Unique Pages in this space: 5
#
# Space Name: shuichi.shitara
# Total Unique Pages in this space: 5
#
# Space Name: Shunichi Kodama
# Total Unique Pages in this space: 5
#
# Space Name: Shunsuke Koshimori
# Total Unique Pages in this space: 5
#
# Space Name: Shunsuke Nakashima
# Total Unique Pages in this space: 5
#
# Space Name: Shun Tsutsui
# Total Unique Pages in this space: 5
#
# Space Name: sibel.narin-farooq
# Total Unique Pages in this space: 5
#
# Space Name: SIEM Info Sec
# Total Unique Pages in this space: 82
#
# Space Name: Silvio Riener
# Total Unique Pages in this space: 5
#
# Space Name: Simeon Tsatskin
# Total Unique Pages in this space: 1
#
# Space Name: Simon Burnett
# Total Unique Pages in this space: 5
#
# Space Name: simone.horsten
# Total Unique Pages in this space: 5
#
# Space Name: Simon Norsworthy
# Total Unique Pages in this space: 5
#
# Space Name: Simon  Williams
# Total Unique Pages in this space: 5
#
# Space Name: siri.oaklander
# Total Unique Pages in this space: 5
#
# Space Name: Sivan Omer
# Total Unique Pages in this space: 5
#
# Space Name: sivan.vardi
# Total Unique Pages in this space: 5
#
# Space Name: Sivan Zadik-Eliasaf
# Total Unique Pages in this space: 5
#
# Space Name: Slack
# Total Unique Pages in this space: 1
#
# Space Name: Slavcho  Ivanov
# Total Unique Pages in this space: 5
#
# Space Name: SMART
# Total Unique Pages in this space: 7
#
# Space Name: Solutions Engineering
# Total Unique Pages in this space: 16
#
# Space Name: Soon Poh Ling
# Total Unique Pages in this space: 5
#
# Space Name: Soumia Benabed
# Total Unique Pages in this space: 5
#
# Space Name: Soya Kamiguchi
# Total Unique Pages in this space: 5
#
# Space Name: SRE
# Total Unique Pages in this space: 48
#
# Space Name: Stav Eini
# Total Unique Pages in this space: 5
#
# Space Name: Steffen Roth
# Total Unique Pages in this space: 5
#
# Space Name: Stein Tiebosch
# Total Unique Pages in this space: 5
#
# Space Name: Stella Bar
# Total Unique Pages in this space: 5
#
# Space Name: Stephan Hoehl
# Total Unique Pages in this space: 1
#
# Space Name: Stephanie Andersen
# Total Unique Pages in this space: 5
#
# Space Name: Stephan Tallent
# Total Unique Pages in this space: 5
#
# Space Name: Stephen Horgan
# Total Unique Pages in this space: 1
#
# Space Name: Stephen Khamis
# Total Unique Pages in this space: 5
#
# Space Name: Sterling Pilkington
# Total Unique Pages in this space: 5
#
# Space Name: Steve Danilov
# Total Unique Pages in this space: 5
#
# Space Name: Steve Fiorentino
# Total Unique Pages in this space: 5
#
# Space Name: steve.mcintyre
# Total Unique Pages in this space: 5
#
# Space Name: Steven Dietz
# Total Unique Pages in this space: 5
#
# Space Name: Stoyan Kostadinov
# Total Unique Pages in this space: 5
#
# Space Name: stuart.lambert
# Total Unique Pages in this space: 5
#
# Space Name: Suematsu,Takao
# Total Unique Pages in this space: 5
#
# Space Name: Suf Dafna
# Total Unique Pages in this space: 5
#
# Space Name: Support
# Total Unique Pages in this space: 149
#
# Space Name: Susan Daly
# Total Unique Pages in this space: 1
#
# Space Name: Svetoslav Doichinov
# Total Unique Pages in this space: 5
#
# Space Name: Syed Fathima
# Total Unique Pages in this space: 5
#
# Space Name: Tadashi Okamura
# Total Unique Pages in this space: 5
#
# Space Name: Tair Itzhak
# Total Unique Pages in this space: 5
#
# Space Name: Takafumi Minoda
# Total Unique Pages in this space: 5
#
# Space Name: Takahiro Koizumi
# Total Unique Pages in this space: 5
#
# Space Name: takashi.uchida
# Total Unique Pages in this space: 5
#
# Space Name: Takayuki Hirose
# Total Unique Pages in this space: 5
#
# Space Name: Takayuki Kamoda
# Total Unique Pages in this space: 5
#
# Space Name: Takayuki Kawasaki
# Total Unique Pages in this space: 5
#
# Space Name: takayuki.murai
# Total Unique Pages in this space: 5
#
# Space Name: Takayuki Sato
# Total Unique Pages in this space: 5
#
# Space Name: Takeshi Sasaki
# Total Unique Pages in this space: 5
#
# Space Name: takuya.inoue
# Total Unique Pages in this space: 5
#
# Space Name: Tal.amiel
# Total Unique Pages in this space: 5
#
# Space Name: Tal  Avrahami
# Total Unique Pages in this space: 5
#
# Space Name: Talent Acquisition
# Total Unique Pages in this space: 1
#
# Space Name: tal genosar
# Total Unique Pages in this space: 5
#
# Space Name: tal himelfarb
# Total Unique Pages in this space: 1
#
# Space Name: tali.danan
# Total Unique Pages in this space: 5
#
# Space Name: Tali Shachak
# Total Unique Pages in this space: 5
#
# Space Name: tal.waitzenberg
# Total Unique Pages in this space: 5
#
# Space Name: Tal Yedgar
# Total Unique Pages in this space: 5
#
# Space Name: tamar.erlich
# Total Unique Pages in this space: 5
#
# Space Name: Tamar Khaskia
# Total Unique Pages in this space: 5
#
# Space Name: Tamir Goldman
# Total Unique Pages in this space: 5
#
# Space Name: Tamir Malka
# Total Unique Pages in this space: 5
#
# Space Name: tan.enghao
# Total Unique Pages in this space: 5
#
# Space Name: Tate Buffington
# Total Unique Pages in this space: 5
#
# Space Name: Tatsuya Igarashi
# Total Unique Pages in this space: 5
#
# Space Name: tatsuya.mori
# Total Unique Pages in this space: 5
#
# Space Name: Tatsuya Tamaki
# Total Unique Pages in this space: 8
#
# Space Name: tatsuya.toyomitsu
# Total Unique Pages in this space: 5
#
# Space Name: Tavor Besser
# Total Unique Pages in this space: 1
#
# Space Name: Tech CX
# Total Unique Pages in this space: 13
#
# Space Name: Tech Excellence
# Total Unique Pages in this space: 102
#
# Space Name: Technical Service Japan
# Total Unique Pages in this space: 88
#
# Space Name: Technical Services EMEA
# Total Unique Pages in this space: 121
#
# Space Name: Technical Terms Glossary
# Total Unique Pages in this space: 50
#
# Space Name: Technology Platform
# Total Unique Pages in this space: 109
#
# Space Name: TechOps
# Total Unique Pages in this space: 449
#
# Space Name: techops guides
# Total Unique Pages in this space: 0
#
# Space Name: Tech Solutions
# Total Unique Pages in this space: 5
#
# Space Name: Tech training & Enablement
# Total Unique Pages in this space: 30
#
# Space Name: Tehila Davidi
# Total Unique Pages in this space: 5
#
# Space Name: terry.suzuki
# Total Unique Pages in this space: 5
#
# Space Name: Testing Personal Space
# Total Unique Pages in this space: 5
#
# Space Name: Test on call
# Total Unique Pages in this space: 1
#
# Space Name: Test Parent Project
# Total Unique Pages in this space: 1
#
# Space Name: Tetsu Maruo
# Total Unique Pages in this space: 5
#
# Space Name: tetsuya.koyama
# Total Unique Pages in this space: 5
#
# Space Name: The Incubator
# Total Unique Pages in this space: 6
#
# Space Name: The Nest
# Total Unique Pages in this space: 36
#
# Space Name: The Probe Encyclopaedia
# Total Unique Pages in this space: 51
#
# Space Name: The Tree
# Total Unique Pages in this space: 24
#
# Space Name: Thomas  Vial
# Total Unique Pages in this space: 5
#
# Space Name: tiberiu.marinica
# Total Unique Pages in this space: 5
#
# Space Name: Tim Amey
# Total Unique Pages in this space: 5
#
# Space Name: Tim Schoenfeld
# Total Unique Pages in this space: 1
#
# Space Name: tim.shipp
# Total Unique Pages in this space: 5
#
# Space Name: Timur Bikbaiev
# Total Unique Pages in this space: 5
#
# Space Name: TLV-IT
# Total Unique Pages in this space: 1
#
# Space Name: TLV SOC
# Total Unique Pages in this space: 98
#
# Space Name: todd.leetham
# Total Unique Pages in this space: 5
#
# Space Name: Tomer Azankot
# Total Unique Pages in this space: 6
#
# Space Name: tomer.druyan
# Total Unique Pages in this space: 5
#
# Space Name: Tomer Israel
# Total Unique Pages in this space: 5
#
# Space Name: Tomer Margolin
# Total Unique Pages in this space: 5
#
# Space Name: Tomer Ravkaie
# Total Unique Pages in this space: 5
#
# Space Name: Tomer Yair
# Total Unique Pages in this space: 5
#
# Space Name: Tom Fakterman
# Total Unique Pages in this space: 5
#
# Space Name: Tomislav Matijak
# Total Unique Pages in this space: 5
#
# Space Name: Tommy Barth
# Total Unique Pages in this space: 1
#
# Space Name: Tomohiro Inoue
# Total Unique Pages in this space: 5
#
# Space Name: Tomohiro Yamashita
# Total Unique Pages in this space: 8
#
# Space Name: Tomohito Oyane
# Total Unique Pages in this space: 5
#
# Space Name: Tomokazu Muneyuki
# Total Unique Pages in this space: 5
#
# Space Name: Tomoki Fukunishi
# Total Unique Pages in this space: 5
#
# Space Name: tomonori.nagano
# Total Unique Pages in this space: 5
#
# Space Name: Tomonori Sawamura
# Total Unique Pages in this space: 5
#
# Space Name: Tomoyuki Higuchi
# Total Unique Pages in this space: 1
#
# Space Name: Tony Dennis
# Total Unique Pages in this space: 5
#
# Space Name: Torsten  Koch
# Total Unique Pages in this space: 5
#
# Space Name: Toshi
# Total Unique Pages in this space: 5
#
# Space Name: Toshiaki Suzuki
# Total Unique Pages in this space: 3
#
# Space Name: Training
# Total Unique Pages in this space: 75
#
# Space Name: Training Future
# Total Unique Pages in this space: 30
#
# Space Name: Travel
# Total Unique Pages in this space: 0
#
# Space Name: Travis Newshott
# Total Unique Pages in this space: 9
#
# Space Name: trevor.eastin
# Total Unique Pages in this space: 5
#
# Space Name: Tristan Elder
# Total Unique Pages in this space: 5
#
# Space Name: Tristan Madani
# Total Unique Pages in this space: 5
#
# Space Name: Tsutomu Wakabayashi
# Total Unique Pages in this space: 5
#
# Space Name: Tue Luu
# Total Unique Pages in this space: 6
#
# Space Name: Tyra Regan
# Total Unique Pages in this space: 1
#
# Space Name: Udi-Yehuda Tamar
# Total Unique Pages in this space: 5
#
# Space Name: UI Dev Chapter
# Total Unique Pages in this space: 24
#
# Space Name: UI Infra
# Total Unique Pages in this space: 35
#
# Space Name: Uma Shukla
# Total Unique Pages in this space: 5
#
# Space Name: Uria Nagar
# Total Unique Pages in this space: 5
#
# Space Name: Uri Sternfeld
# Total Unique Pages in this space: 7
#
# Space Name: Utsav Sanghani
# Total Unique Pages in this space: 5
#
# Space Name: UX/UI studio
# Total Unique Pages in this space: 158
#
# Space Name: uzi.golan
# Total Unique Pages in this space: 5
#
# Space Name: Vacay Your Way!
# Total Unique Pages in this space: 1
#
# Space Name: Vadim Entov
# Total Unique Pages in this space: 5
#
# Space Name: Vadim Pogulievsky
# Total Unique Pages in this space: 1
#
# Space Name: Vadym.Nechyporuk
# Total Unique Pages in this space: 5
#
# Space Name: Valentine Bernard
# Total Unique Pages in this space: 5
#
# Space Name: Valeria Raif
# Total Unique Pages in this space: 5
#
# Space Name: Vanessa Celestin
# Total Unique Pages in this space: 5
#
# Space Name: Vardit Goel
# Total Unique Pages in this space: 5
#
# Space Name: Vasyl.Shestak
# Total Unique Pages in this space: 5
#
# Space Name: Vered Gomma
# Total Unique Pages in this space: 5
#
# Space Name: Vered Ovadia
# Total Unique Pages in this space: 5
#
# Space Name: veronique.assie
# Total Unique Pages in this space: 5
#
# Space Name: Vicki Lindem
# Total Unique Pages in this space: 5
#
# Space Name: Victor Basin
# Total Unique Pages in this space: 5
#
# Space Name: Victor Masterman
# Total Unique Pages in this space: 5
#
# Space Name: Vincent Bariteau
# Total Unique Pages in this space: 5
#
# Space Name: vincent.lek
# Total Unique Pages in this space: 5
#
# Space Name: Vincent Nomura
# Total Unique Pages in this space: 5
#
# Space Name: Virendra Yadav
# Total Unique Pages in this space: 1
#
# Space Name: Vision BI Cybereason
# Total Unique Pages in this space: 1
#
# Space Name: Vitaly Elyashev
# Total Unique Pages in this space: 8
#
# Space Name: Vitor A Serafim
# Total Unique Pages in this space: 1
#
# Space Name: Vlad Dumitrache
# Total Unique Pages in this space: 1
#
# Space Name: vladimir.kamenev
# Total Unique Pages in this space: 5
#
# Space Name: Vlad Ogranovich (EMEA)
# Total Unique Pages in this space: 5
#
# Space Name: Vlado Vajdic
# Total Unique Pages in this space: 1
#
# Space Name: Vladyslav.Kozhukhov
# Total Unique Pages in this space: 5
#
# Space Name: Vladyslav Kromkach
# Total Unique Pages in this space: 1
#
# Space Name: volodymyr.roshko
# Total Unique Pages in this space: 5
#
# Space Name: Vulnerability management
# Total Unique Pages in this space: 1
#
# Space Name: Wakako Kawabe
# Total Unique Pages in this space: 5
#
# Space Name: Warren Kristian Hui
# Total Unique Pages in this space: 5
#
# Space Name: Wataru Enomoto
# Total Unique Pages in this space: 5
#
# Space Name: Wataru Miyazaki
# Total Unique Pages in this space: 5
#
# Space Name: Website
# Total Unique Pages in this space: 31
#
# Space Name: Wilhelm Klemm
# Total Unique Pages in this space: 5
#
# Space Name: William Stewart
# Total Unique Pages in this space: 5
#
# Space Name: william.udovich
# Total Unique Pages in this space: 5
#
# Space Name: Windows Collection Squad
# Total Unique Pages in this space: 87
#
# Space Name: Windows Kernel Squad
# Total Unique Pages in this space: 98
#
# Space Name: wojciech.kolodziejczyk
# Total Unique Pages in this space: 5
#
# Space Name: Wouter Marien
# Total Unique Pages in this space: 5
#
# Space Name: xavier.wood
# Total Unique Pages in this space: 5
#
# Space Name: XDR Product Requirements
# Total Unique Pages in this space: 103
#
# Space Name: XDR Team
# Total Unique Pages in this space: 150
#
# Space Name: xinwang zhang
# Total Unique Pages in this space: 5
#
# Space Name: xinxin.ocampo
# Total Unique Pages in this space: 5
#
# Space Name: Yael Alaluf
# Total Unique Pages in this space: 5
#
# Space Name: yahav.menashe
# Total Unique Pages in this space: 5
#
# Space Name: Yair Asraf
# Total Unique Pages in this space: 5
#
# Space Name: yair.martonovich
# Total Unique Pages in this space: 5
#
# Space Name: yaki.sicron
# Total Unique Pages in this space: 5
#
# Space Name: yaniv.bigger
# Total Unique Pages in this space: 5
#
# Space Name: Yanjun Wang
# Total Unique Pages in this space: 1
#
# Space Name: Yarden Kovrigaro
# Total Unique Pages in this space: 5
#
# Space Name: Yariv Hashai
# Total Unique Pages in this space: 0
#
# Space Name: Yaron Cohen
# Total Unique Pages in this space: 10
#
# Space Name: Yaroslav Yarmoshyk
# Total Unique Pages in this space: 12
#
# Space Name: Yasmin Klein
# Total Unique Pages in this space: 5
#
# Space Name: Yasuaki Kubota
# Total Unique Pages in this space: 5
#
# Space Name: Yasuhiro Uehara
# Total Unique Pages in this space: 5
#
# Space Name: Yasuji Tanaka
# Total Unique Pages in this space: 5
#
# Space Name: Yasuo Suzuki
# Total Unique Pages in this space: 5
#
# Space Name: Yasuyuki Miura
# Total Unique Pages in this space: 5
#
# Space Name: Yavuz  Oezmen
# Total Unique Pages in this space: 5
#
# Space Name: Yeongjin Pak
# Total Unique Pages in this space: 5
#
# Space Name: Yi Jun Koh
# Total Unique Pages in this space: 5
#
# Space Name: yoav lapin
# Total Unique Pages in this space: 5
#
# Space Name: Yohei Hashiguchi
# Total Unique Pages in this space: 5
#
# Space Name: Yoh Honda
# Total Unique Pages in this space: 5
#
# Space Name: Yoichi Kurasawa
# Total Unique Pages in this space: 5
#
# Space Name: yoichi.takezawa
# Total Unique Pages in this space: 5
#
# Space Name: Yoko Edaki
# Total Unique Pages in this space: 5
#
# Space Name: yona.schoemann
# Total Unique Pages in this space: 8
#
# Space Name: yonatan.aldaag
# Total Unique Pages in this space: 5
#
# Space Name: Yonatan Gidnian
# Total Unique Pages in this space: 6
#
# Space Name: Yonatan Perry
# Total Unique Pages in this space: 0
#
# Space Name: Yonatan Striem-Amit
# Total Unique Pages in this space: 5
#
# Space Name: yoni.machlin
# Total Unique Pages in this space: 5
#
# Space Name: yoni.touitou
# Total Unique Pages in this space: 5
#
# Space Name: yoram.levi
# Total Unique Pages in this space: 5
#
# Space Name: yoshiaki.oiyama
# Total Unique Pages in this space: 5
#
# Space Name: Yoshihiro Fujimoto
# Total Unique Pages in this space: 5
#
# Space Name: Yoshimasa Nakamura
# Total Unique Pages in this space: 5
#
# Space Name: yoshinobu.kasuya
# Total Unique Pages in this space: 5
#
# Space Name: Yoshitaka Kosaka
# Total Unique Pages in this space: 5
#
# Space Name: Yossi Rachman
# Total Unique Pages in this space: 5
#
# Space Name: Yossi Srour
# Total Unique Pages in this space: 5
#
# Space Name: Yotam Roch
# Total Unique Pages in this space: 0
#
# Space Name: yugo.soma
# Total Unique Pages in this space: 5
#
# Space Name: Yu Guangyuan
# Total Unique Pages in this space: 5
#
# Space Name: Yuichi Takahashi
# Total Unique Pages in this space: 5
#
# Space Name: yu.ishitani
# Total Unique Pages in this space: 5
#
# Space Name: Yuji Hayamizu
# Total Unique Pages in this space: 5
#
# Space Name: Yukie Miyazaki
# Total Unique Pages in this space: 5
#
# Space Name: Yukinobu Moriya
# Total Unique Pages in this space: 5
#
# Space Name: Yukio Adachi
# Total Unique Pages in this space: 5
#
# Space Name: Yuki Shibuya
# Total Unique Pages in this space: 5
#
# Space Name: Yulia.Prego
# Total Unique Pages in this space: 5
#
# Space Name: Yumiko Sato
# Total Unique Pages in this space: 5
#
# Space Name: yumi.nishishiro
# Total Unique Pages in this space: 5
#
# Space Name: yuri.dorohov
# Total Unique Pages in this space: 5
#
# Space Name: yuri.machlin
# Total Unique Pages in this space: 5
#
# Space Name: Yusuke Shimizu
# Total Unique Pages in this space: 5
#
# Space Name: Yutaka Matsuoka
# Total Unique Pages in this space: 5
#
# Space Name: Yutaka Shimowada
# Total Unique Pages in this space: 1
#
# Space Name: Yuta Matsubara
# Total Unique Pages in this space: 1
#
# Space Name: Yuval Boker
# Total Unique Pages in this space: 14
#
# Space Name: Yuval Chuddy
# Total Unique Pages in this space: 5
#
# Space Name: Yuval Kovacs
# Total Unique Pages in this space: 5
#
# Space Name: Yuya Fune
# Total Unique Pages in this space: 5
#
# Space Name: Yuya Imamura
# Total Unique Pages in this space: 5
#
# Space Name: Zachary Albert
# Total Unique Pages in this space: 5
#
# Space Name: Zachary Perschon
# Total Unique Pages in this space: 5
#
# Space Name: Zach Perrego
# Total Unique Pages in this space: 5
#
# Space Name: Zahi Ohayon
# Total Unique Pages in this space: 5
#
# Space Name: Ziyi Fuan
# Total Unique Pages in this space: 1
#
# Space Name: Zohar Gershoni
# Total Unique Pages in this space: 5
#
# Space Name: zvika.meiseles
# Total Unique Pages in this space: 6
#
#
# Total unique spaces in Confluence: 587
# Total unique pages in Confluence: 9636
# {'total_unique_spaces': 587, 'total_unique_pages': 9636}

# %%
import csv

def combine_csv_files(file1, file2, output_file):
    with open(file1, 'r', newline='', encoding='utf-8') as f1, open(file2, 'r', newline='', encoding='utf-8') as f2, open(output_file, 'w', newline='', encoding='utf-8') as out_file:
        reader1 = csv.reader(f1)
        reader2 = csv.reader(f2)
        writer = csv.writer(out_file)

        # Write headers from the first file
        headers = next(reader1)
        writer.writerow(headers)

        # Write rows from the first file
        for row in reader1:
            writer.writerow(row)

        # Skip headers in the second file
        next(reader2)

        # Write rows from the second file
        for row in reader2:
            writer.writerow(row)

# Combine CSV files
combine_csv_files('confluence_pages.csv', 'confluence_pages(1000+).csv', 'combined_confluence_pages.csv')
